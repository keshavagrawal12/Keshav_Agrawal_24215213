# %%
## 1. Importing Libraries
import tensorflow as tf
import numpy as np
#tensorflow: Used to build and train neural networks.
#numpy: Used for numerical computations and array manipulations.

# 2. Defining the Dataset
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y = np.array([[0], [0], [0], [1]], dtype=np.float32)
# X is the input dataset representing the AND gate inputs.
# y is the output label, where the output is 1 only when both inputs are 1, as per the truth table of the AND gate.#

#3. Building the Neural Network Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(4, input_dim=2, activation='relu'),  # Hidden layer
    tf.keras.layers.Dense(1, activation='sigmoid')              # Output layer
])
# Sequential: Creates a linear stack of layers.
# First Layer (Hidden Layer):
# Dense(4): Fully connected layer with 4 neurons.
# input_dim=2: Accepts 2 input features (each input sample has two values).
# activation='relu': Uses ReLU activation to introduce non-linearity.
# Second Layer (Output Layer):
# Dense(1): Outputs a single value.
# activation='sigmoid': Outputs a value between 0 and 1, suitable for binary classification.#

# 4. Compiling the Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# optimizer='adam': Efficient optimization algorithm.
# loss='binary_crossentropy': Used for binary classification problems.
# metrics=['accuracy']: Tracks accuracy during training.

#### Predictions BEFORE training
print("Predictions BEFORE training:")
untrained_predictions = model.predict(X)
for i, pred in enumerate(untrained_predictions):
    print(f"Input: {X[i]} => Predicted: {round(float(pred), 4)} => Class: {int(pred >= 0)}")

# 5. Training the Model
model.fit(X, y, epochs=10, verbose=2)
# Trains the model for 10 epochs.
#verbose=0: Suppresses output during training.

# 6. Evaluating and Making Predictions
predictions = model.predict(X)
#Predicts outputs for all input combinations.
for i, pred in enumerate(predictions):
    print(f"Input: {X[i]} => Predicted: {round(float(pred), 4)} => Class: {int(pred >= 0.5)}")

# Rounds and prints the predicted output and its classified label (0 or 1).
#A threshold of 0.5 is used to convert the sigmoid output to class labels.

# Result
# Before training, the model behaves randomly because it has no knowledge of the pattern.
# After training, it learns to approximate the AND function.
# Out:
# Predictions BEFORE training:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Input: [0. 0.] => Predicted: 0.5 => Class: 1
# Input: [0. 1.] => Predicted: 0.4455 => Class: 1
# Input: [1. 0.] => Predicted: 0.2971 => Class: 1
# Input: [1. 1.] => Predicted: 0.2404 => Class: 1
# Epoch 1/10
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /var/folders/gw/r_nx773s5z74vwzcydpj0lw40000gn/T/ipykernel_10104/2232223250.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(f"Input: {X[i]} => Predicted: {round(float(pred), 4)} => Class: {int(pred >= 0)}")
# 1/1 - 0s - 194ms/step - accuracy: 0.7500 - loss: 0.7652
# Epoch 2/10
# 1/1 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.7646
# Epoch 3/10
# 1/1 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.7638
# Epoch 4/10
# 1/1 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.7630
# Epoch 5/10
# 1/1 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.7622
# Epoch 6/10
# 1/1 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.7615
# Epoch 7/10
# 1/1 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.7607
# Epoch 8/10
# 1/1 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.7600
# Epoch 9/10
# 1/1 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.7593
# Epoch 10/10
# 1/1 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.7585
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Input: [0. 0.] => Predicted: 0.4975 => Class: 0
# Input: [0. 1.] => Predicted: 0.451 => Class: 0
# Input: [1. 0.] => Predicted: 0.302 => Class: 0
# Input: [1. 1.] => Predicted: 0.2506 => Class: 0
# /var/folders/gw/r_nx773s5z74vwzcydpj0lw40000gn/T/ipykernel_10104/2232223250.py:48: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(f"Input: {X[i]} => Predicted: {round(float(pred), 4)} => Class: {int(pred >= 0.5)}")
