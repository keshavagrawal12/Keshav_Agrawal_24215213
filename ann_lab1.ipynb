# %% [markdown]
# LAB 1: LOAN APPROVAL PERCEPTRON

# %%
import numpy as np

def step_function(x):
    return 1 if x >= 0 else 0

class Perceptron:
    def __init__(self, input_size, learning_rate=0.1):
        self.weights = np.zeros(input_size)
        self.bias = 0
        self.lr = learning_rate

    def predict(self, x):
        z = np.dot(x, self.weights) + self.bias
        return step_function(z)

    def train(self, X, y, epochs=10):
        for epoch in range(epochs):
            for xi, target in zip(X, y):
                prediction = self.predict(xi)
                error = target - prediction
                self.weights += self.lr * error * xi
                self.bias += self.lr * error

# Features: [income_sufficient (1=yes), good_credit_score (1=yes)]
X = np.array([[0,0],[0,1],[1,0],[1,1]])
# Loan is approved ONLY if BOTH conditions are true (AND logic)
y = np.array([0,0,0,1])

p = Perceptron(input_size=2)
p.train(X, y, epochs=10)

labels = ["Low income, Bad credit", "Low income, Good credit",
          "High income, Bad credit", "High income, Good credit"]

print("Loan Approval Predictions:")
for xi, label in zip(X, labels):
    result = "APPROVED" if p.predict(xi) == 1 else "REJECTED"
    print(f"{label:30s} -> {result}")
# Out:
# Loan Approval Predictions:
# Low income, Bad credit         -> REJECTED
# Low income, Good credit        -> REJECTED
# High income, Bad credit        -> REJECTED
# High income, Good credit       -> APPROVED
